# %% [markdown]
# Puntos, si el ejericicio te pide remplazar, entonces ocuparas el array mutable.
#
# Si el ejercicio te pide, consultar u obtener el indice, con strings literal es mas que suficiente.
