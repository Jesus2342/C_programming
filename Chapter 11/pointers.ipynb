# %% [markdown]
# # Declaring a pointer

# %% [markdown]
# C requires that every pointer variable point only to objects of a particular type (referenced type)

# %% [markdown]
# int *p    // points only to integers
# double *q  // points only to doubles
# char *r  // points only to characters

# %% [markdown]
# ¿How to read a pointer?
#
# . The trick is to read them backward
#
# const int *pci;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Address of Operator

# %% [markdown]
# //Those are the valid forms to initialize a pointer variable at the time we declare it.
#
#
# int num, *pi = &num;
#
# OR
#
#
# int num;
# int *pi = &num;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Address of num and p
# printf("Address of num  is %d\n", &num ) --- Address of num is 100.
# printf("Address of p is %d\n, &p) -- Address of pi is 104.
#
#
# values of num and p
# printf("Value of num %d", num) ---Value of num is 0
# printf("Value of p %d, num) --- Value of pi is 100

# %% [markdown]
# ## Indirect Operator

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# //Once a pointer variable points to an object, if we use *(indirection) operator to access what's stored in the object.
#
# printf("value of num %d, num )  Aqui num es 0
#
#
# printf("Value of p is %d\n", *p) Aqui pi es 0
#
# OR
#
# printf("Value of pi is %p, (void*)p) Aqui pi es 0. (RECOMMENDED)

# %% [markdown]
# At least for now do not initialize a pointer value without declare it.
#
# Example
#
# int *p;
# printf("%d", *p) WRONG
#
#
# int *p;
# *p = 1; WRONG

# %% [markdown]
# ## ARRAYS

# %% [markdown]
# This sets the pointer to NULL (address 0).
# That means max does not point to any valid memory.
#
# int *max = 0;

# %% [markdown]
# int *find_largest(int a[], int n){
#
#     int *max = &a[0];  /* LEGAL */
#
#     /* int *max = 0 ***WRONG*** */
#
#
#     for(int i = 0; i < n; i++){
#         if(*max < a[i]){
#             *max = a[i];
#         }
#     }
#
#     return max;
# }

# %% [markdown]
# ## PASSING ARGUMENTS TO A FUCNTION USING CHAR BUFFERS

# %% [markdown]
# Remmeber that char arrays or int arrays do not need to specify the address, since they already pass the address itself.

# %% [markdown]
# void find_closest_flight(int desired_time_min, char *response); prototype
#
# int desired_time = (hour * 60) + min;
# char best_time[10];
#
#
# find_closest_flight(desired_time, &best_time); ***WRONG***
#
# find_closest_flight(desired_time, best_time); **LEGAL**
